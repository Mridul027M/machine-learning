# %% [markdown]
# <a href="https://colab.research.google.com/github/Mridul027M/machine-learning/blob/main/Assign3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot
data=pd.read_csv("/content/A3_Monday.csv - Sheet1.csv")
#print(data)

edata = data.iloc[: , 1:7]
#print(edata)
fea=edata.shape[1]
patt=edata.shape[0]
print("number of features-",fea)
print("number of patterns-",patt)
range=[]
max=data["price"].max()
min=data["price"].min()
range.append(min)
range.append(max)
print(range)
mat=list(edata)
################################################################
splitX=data.sample(frac=0.1,random_state=10)
splitY=data.sample(frac=0.9,random_state=10)
print("x------\n")
print(splitX)
print("y------\n")
print(splitY)
print("\n")
###############################################################
for i in mat:
  print('\n')
  print(i)
  print(f"Mean,median,mode in { i} column")
  print("Mean",data[i].mean())
  print("Median",data[i].median())
  print("Mode",data[i].mode())
  print("Standard Deviation",data[i].std())

data['mean'] = data.iloc[: ,1:].mean(axis=1)
print(data['mean'])

print(data.stack().mean())
print(data.stack().median())
print(data.stack().mode())
print(data.stack().std())



#################################################################

import matplotlib.pyplot as plt
sdata=pd.read_csv("/content/student_scores.csv")

x = sdata["Hours"].tolist()
y = sdata["Scores"].tolist()
  
plt.plot(x, y)
  
plt.xlabel('x - axis')

plt.ylabel('y - axis')
  
plt.title('My first graph!')

plt.show()
# Out:
# number of features- 6
# number of patterns- 100
# [153000.0, 2000000.0]
# x------
#
#     id  bedrooms  grade  sqft_living  bathrooms  floors  yr_built     price
# 19  20         3      7         1250        1.0       1      1969  230000.0
# 14  15         5      7         1810        2.0       2      1900  530000.0
# 43  44         3      7         1570        1.0       2      1922  685000.0
# 37  38         4      8         2360        2.0       2      1904  640000.0
# 66  67         4     10         2720        3.0       2      1989  975000.0
# 3    4         4      7         1960        3.0       1      1965  604000.0
# 79  80         4     10         3450        3.0       2      2002  720000.0
# 41  42         4      8         4220        2.0       1      1984  775000.0
# 38  39         4      7         1220        1.0       1      1969  240000.0
# 68  69         3      7         1000        1.0       1      1968  204000.0
# y------
#
# ...
